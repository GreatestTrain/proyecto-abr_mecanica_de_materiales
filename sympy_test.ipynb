# %%
import os

# %%
os.environ["USE_SYMENGINE"]="1"

# %%
from sympy import *

# %%
_x = Symbol("x")

# %%
expr = sqrt(_x) + 2*_x
expr
# Out:
# sqrt(x) + 2*x

# %%
a = expr.subs(_x, I).n(10)

# %%
expr.sub
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5216\2325666720.py in <cell line: 1>()
# ----> 1 expr.subs(_x)
#
# c:\Users\Cesar\scoop\apps\mambaforge\current\envs\materiales\lib\site-packages\sympy\core\basic.py in subs(self, *args, **kwargs)
#     920                 sequence = sequence.items()
#     921             elif not iterable(sequence):
# --> 922                 raise ValueError(filldedent("""
#     923                    When a single argument is passed to subs
#     924                    it should be a dictionary of old: new pairs or an iterable
#
# ValueError:
# When a single argument is passed to subs it should be a dictionary of
# old: new pairs or an iterable of (old, new) tuples.

# %%
str(a)
# Out:
# '0.7071067812 + 2.707106781*I'

# %%
from sympy import integrate, Ynm
import symengine as s

# %%
__x = s.Symbol("x")
expr2 = s.sqrt(__x) + 2*__x

# %%
f = 0*__x + integrate(expr2)
f
# Out:
# x**2 + (2/3)*x**(3/2)

# %%
expr2.subs(__x, s.I).n(100000)
# Out:
# 0.... + 2....*I
