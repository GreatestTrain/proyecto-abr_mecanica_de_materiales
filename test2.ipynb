# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sympy.plotting import plot
from sympy import solve, Eq, sympify, integrate, Symbol, symbols

# %%
from mm.forces import *
from mm.symbols import _x
from mm.structures import *
# from mm import *

# %%
L = 4
m = 10
p = 50
mo = p*L

# %%
viga = Beam()
viga.addMoment(Moment(200),0)
viga.addPointLoad(PointLoad(50),0)
viga.addPointLoad(PointLoad(-50),L)

# %%
plot(viga.bmd())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot(viga.sfd())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
